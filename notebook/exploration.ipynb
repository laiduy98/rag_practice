# %%
from johnsnowlabs import nlp

spark = nlp.start()
spark
# Out:
# 24/11/13 18:30:57 WARN Utils: Your hostname, Khangs-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 10.45.5.81 instead (on interface en0)
# 24/11/13 18:30:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 24/11/13 18:30:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/13 18:30:58 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 👌 Launched cpu optimized session with with: 🚀Spark-NLP==5.5.0, running on ⚡ PySpark==3.5.3
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.45.5.81:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
# ...
